# %%
# Importing Required Libraries
import numpy as np
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Dataset (basic e.g., house size(sq ft) vs house price(Dollars))
X = np.array([[1400], [1600], [1700], [1875], [1100], [1550], [2450], [2350], [1425], [1700]])
y = np.array([245000, 312000, 279000, 308000, 199000, 219000, 405000, 382500, 255000, 298720])

# %%
# Splitting Dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
# Ridge Regression Model and Predictions
ridge_model = Ridge(alpha=1)
ridge_model.fit(X_train, y_train)

y_pred_ridge = ridge_model.predict(X_test)

# Lasso Regression Model and Predictions
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)

y_pred_lasso = lasso_model.predict(X_test)

# %%
# Evaluate Both the Regression 
mse_l2 = mean_squared_error(y_test, y_pred_ridge)
print(f"Ridge (L2) Mean Squared Error: {mse_l2:.4f}")

mse_l1 = mean_squared_error(y_test, y_pred_lasso)
print(f"Lasso (L1) Mean Squared Error: {mse_l1:.4f}")
# Out:
# Ridge (L2) Mean Squared Error: 1182986445.5297
# Lasso (L1) Mean Squared Error: 1182987848.7717
